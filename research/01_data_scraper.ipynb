# %%
import os

# %%
# %pwd
# Out:
# '/home/tiva/PycharmProjects/HeadlineGenerator/notebook'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# '/home/tiva/PycharmProjects/HeadlineGenerator'

# %%
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass(frozen=True)
class DataScraperConfig:
    root_dir: Path
    save_dir: Path
    source_url: str
    categories: list
    max_pages: int

# %%
from headlineGenerator.constants import *
from headlineGenerator.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self, config_filepath=CONFIG_FILEPATH, params_filepath=PARAMS_FILEPATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_scraper_config(self) -> DataScraperConfig:
        config = self.config.data_scraper

        create_directories([config.root_dir])
        
        data_scraper_config = DataScraperConfig(
            root_dir=config.root_dir,
            save_dir=config.save_dir,
            source_url=config.source_url,
            categories=config.categories,
            max_pages=config.max_pages
        )

        return data_scraper_config

# %%
import os
import csv
import httpx
from selectolax.parser import HTMLParser
from headlineGenerator.entity import Content
from headlineGenerator.logging import logger
from headlineGenerator.utils.common import get_size
from dataclasses import asdict, dataclass, fields

# %%
class DataScraper:
    def __init__(self, config: DataScraperConfig):
        self.config = config


    def get_html(self, url, **kwargs):
        headers = {"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:121.0) Gecko/20100101 Firefox/121.0"}
        timeout = httpx.Timeout(connect=None, read=None, write=5, pool=5)
        # page keyword is used for getting news from a specific page
        if kwargs.get("page"):
            resp = httpx.get(url + f"page/{kwargs.get('page')}/", headers=headers, timeout=timeout, follow_redirects=True)
        else:
            resp = httpx.get(url, headers=headers, timeout=timeout, follow_redirects=True)

        html = HTMLParser(resp.text)
        # handle when page number is exceeded
        if html.css_first("title").text() == "Page not found | AIT LIVE":
            logger.info(f"No results found while requesting URL {resp.url}. Page Limit Exceeded")
            return False

        return html


    def extract_text(self, html, selector):
        try:
            return html.css_first(selector).text(strip=True)
        except AttributeError:
            return None
        except Exception as e:
            raise e


    def extract_attribute(self, html, selector, attribute):
        try:
            return html.css_first(selector).attributes[attribute]
        except AttributeError:
            return None
        except Exception as e:
            raise e


    def get_page_url(self, html: HTMLParser):
        blog_contents = html.css("div.blog-content div.block-inner div[data-pid]")

        for content in blog_contents:
            yield content.css_first("h4.entry-title a").attributes["href"]


    def get_page_content(self, html: HTMLParser, url: str):
        content = Content(
            headline=self.extract_text(html, "h1.s-title"),
            last_update=self.extract_attribute(html, "time.updated-date", "datetime"),
            writer=self.extract_text(html, "span.meta-el.meta-custom.meta-bold"),
            editor=self.extract_text(html, "div[itemprop=articleBody] p:nth-last-of-type(2) strong"),
            summary=self.extract_text(html, "div[itemprop=articleBody] p strong"),
            main_story=" ".join([node.text() for node in html.css("div[itemprop=articleBody] p:not(:has(strong))")]).strip(),
            page_url=url
        )

        return asdict(content)

    def export_to_csv(self, contents: list, path: Path):
        field_names = [field.name for field in fields(Content)]
        with open(path, "w") as file:
            writer = csv.DictWriter(file, field_names)
            writer.writeheader()
            writer.writerows(contents)

    def scrape_data(self):        
        for category in self.config.categories:
            contents = []
            data_count = 1
        
            logger.info(f"'\n>>> {category.upper()} CATEGORY'")
            
            for i in range(1, self.config.max_pages):
                logger.info(f"Scraping page {i}/{self.config.max_pages}")
                url = self.config.source_url + category + "/"
                html = self.get_html(url, page=i)
                if html is False:
                    break
                content_urls = self.get_page_url(html)

                for content_url in content_urls:
                    content_html = self.get_html(content_url)
                    logger.info(f"#{data_count} ==> {content_html.css_first('title').text()}")
                    content = self.get_page_content(content_html, content_url)
                    contents.append(content)
                    data_count += 1
                    logger.info("-" * 200)
                    
            save_path = os.path.join(self.config.save_dir, f"{category}_contents.csv")
            self.export_to_csv(contents, save_path)
            logger.info(f"{category.upper()} CONTENTS SAVED TO CSV SUCCESSFULLY.")

# %%
try:
    config = ConfigurationManager()
    data_scraper_config = config.get_data_scraper_config()
    data_scraper = DataScraper(config=data_scraper_config)
    data_scraper.scrape_data()
except Exception as e:
    raise e
# Out:
# [2024-03-13 09:24:38,076 || INFO || common || yaml file : config.yaml loaded successfully]
# [2024-03-13 09:24:38,080 || INFO || common || yaml file : params.yaml loaded successfully]
# [2024-03-13 09:24:38,082 || INFO || common || created directory at artifacts]
# [2024-03-13 09:24:38,084 || INFO || common || created directory at artifacts/data_scraper]
# [2024-03-13 09:24:38,085 || INFO || 1657421991 || '
# >>> BUSINESS CATEGORY']
# [2024-03-13 09:24:38,087 || INFO || 1657421991 || Scraping page 1/2]
# [2024-03-13 09:26:49,717 || INFO || _client || HTTP Request: GET https://ait.live/category/business/page/1/ "HTTP/1.1 301 Moved Permanently"]
# [2024-03-13 09:26:50,160 || INFO || _client || HTTP Request: GET https://ait.live/category/business/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:51,417 || INFO || _client || HTTP Request: GET https://ait.live/nigeria-qatar-sign-seven-agreements-as-president-tinubu-ends-state-visit/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:51,729 || INFO || 1657421991 || #1 ==> Nigeria, Qatar sign seven agreements as President Tinubu ends state visit | AIT LIVE]
# [2024-03-13 09:26:51,732 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:52,848 || INFO || _client || HTTP Request: GET https://ait.live/stakeholders-advocate-for-industrial-policy-laws-designed-to-lower-import-costs-in-nigeria/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:53,024 || INFO || 1657421991 || #2 ==> Stakeholders Advocate for Industrial Policy Laws Designed to Lower Import Costs in Nigeria | AIT LIVE]
# [2024-03-13 09:26:53,026 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:54,116 || INFO || _client || HTTP Request: GET https://ait.live/food-production-fg-commissions-farm-housing-units-empowerment-centres-in-borno/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:54,432 || INFO || 1657421991 || #3 ==> Food Production : FG Commissions Farm Housing Units, Empowerment Centres In Borno | AIT LIVE]
# [2024-03-13 09:26:54,434 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:55,333 || INFO || _client || HTTP Request: GET https://ait.live/hike-in-price-of-aviation-fuel-threatens-domestic-operations/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:55,509 || INFO || 1657421991 || #4 ==> Hike in price of Aviation fuel threatens domestic operations | AIT LIVE]
# [2024-03-13 09:26:55,511 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:56,670 || INFO || _client || HTTP Request: GET https://ait.live/senate-summons-cbn-governor-on-state-of-economy-free-fall-of-naira/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:56,922 || INFO || 1657421991 || #5 ==> Senate Summons CBN Governor On State Of Economy , Free Fall Of Naira | AIT LIVE]
# [2024-03-13 09:26:56,925 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:58,022 || INFO || _client || HTTP Request: GET https://ait.live/media-officials-proposes-infrastructure-plan-to-ease-nigeria-supply-chain-congestion/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:58,189 || INFO || 1657421991 || #6 ==> Media Officials Proposes Infrastructure Plan to Ease Nigeria Supply Chain Congestion | AIT LIVE]
# [2024-03-13 09:26:58,192 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:26:59,390 || INFO || _client || HTTP Request: GET https://ait.live/icpc-firs-initiate-talks-on-combating-financial-tax-frauds-in-nigeria/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:26:59,558 || INFO || 1657421991 || #7 ==> ICPC, FIRS Initiate Talks On Combating Financial Tax Frauds In Nigeria | AIT LIVE]
# [2024-03-13 09:26:59,560 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:00,656 || INFO || _client || HTTP Request: GET https://ait.live/vp-shettima-woos-more-foreign-investors-at-world-economic-forum/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:00,829 || INFO || 1657421991 || #8 ==> VP Shettima Woos More Foreign Investors At World Economic Forum | AIT LIVE]
# [2024-03-13 09:27:00,831 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:02,005 || INFO || _client || HTTP Request: GET https://ait.live/nigerian-government-will-approve-shell-onshore-divestment-says-lokpobiri/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:02,153 || INFO || 1657421991 || #9 ==> Nigerian Government Will Approve Shell Onshore Divestment, Says Lokpobiri | AIT LIVE]
# [2024-03-13 09:27:02,155 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:03,307 || INFO || _client || HTTP Request: GET https://ait.live/cbn-pays-2bn-to-clear-fx-backlog-sanctions-await-market-defaulters/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:03,526 || INFO || 1657421991 || #10 ==> CBN pays $2bn To Clear FX Backlog, sanctions await market Defaulters | AIT LIVE]
# [2024-03-13 09:27:03,528 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:04,716 || INFO || _client || HTTP Request: GET https://ait.live/nigerias-inflation-rises-to-28-92-in-december-2023/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:04,853 || INFO || 1657421991 || #11 ==> Nigeria’s Inflation Rises To 28.92% In December 2023 | AIT LIVE]
# [2024-03-13 09:27:04,856 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:06,067 || INFO || _client || HTTP Request: GET https://ait.live/advocacy-group-announces-legislation-to-lower-nigerias-soaring-lnflation/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:06,229 || INFO || 1657421991 || #12 ==> Advocacy Group Announces Legislation To Lower Nigeria’s Soaring Inflation | AIT LIVE]
# [2024-03-13 09:27:06,231 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:06,235 || INFO || 1657421991 || BUSINESS CONTENTS SAVED TO CSV SUCCESSFULLY.]
# [2024-03-13 09:27:06,237 || INFO || 1657421991 || '
# >>> ENTERTAINMENT CATEGORY']
# [2024-03-13 09:27:06,239 || INFO || 1657421991 || Scraping page 1/2]
# [2024-03-13 09:27:09,207 || INFO || _client || HTTP Request: GET https://ait.live/category/entertainment/page/1/ "HTTP/1.1 301 Moved Permanently"]
# [2024-03-13 09:27:10,002 || INFO || _client || HTTP Request: GET https://ait.live/category/entertainment/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:13,089 || INFO || _client || HTTP Request: GET https://ait.live/mohbad-bereaved-mother-accuses-ex-husband-of-delay-in-sons-burial/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:13,427 || INFO || 1657421991 || #1 ==> MohBad: Bereaved mother accuses Ex-husband of delay in son's burial | AIT LIVE]
# [2024-03-13 09:27:13,430 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:15,117 || INFO || _client || HTTP Request: GET https://ait.live/american-rapper-kanye-west-visits-nigeria-in-december/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:15,243 || INFO || 1657421991 || #2 ==> American rapper, Kanye West visits Nigeria in December | AIT LIVE]
# [2024-03-13 09:27:15,247 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:17,069 || INFO || _client || HTTP Request: GET https://ait.live/renowned-theatre-arts-icon-olujimi-solanke-dies-at-81/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:17,233 || INFO || 1657421991 || #3 ==> Renowned Theatre Arts icon, Olujimi Solanke dies at 81 | AIT LIVE]
# [2024-03-13 09:27:17,236 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:37,032 || INFO || _client || HTTP Request: GET https://ait.live/66th-grammys-jay-z-slams-recording-academy-for-snubbing-his-wife-beyonce/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:37,086 || INFO || 1657421991 || #4 ==> 66th Grammys: Jay Z slams Recording Academy for snubbing his wife, Beyonce | AIT LIVE]
# [2024-03-13 09:27:37,088 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:39,147 || INFO || _client || HTTP Request: GET https://ait.live/nigerian-afrobeats-singers-burnaboy-asake-rema-bag-nominations/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:39,425 || INFO || 1657421991 || #5 ==> Nigerian Afrobeats Singers Burnaboy Asake, Rema Bag Nominations | AIT LIVE]
# [2024-03-13 09:27:39,427 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:40,757 || INFO || _client || HTTP Request: GET https://ait.live/justina-okpoh-celebrates-gods-faithfulness-and-mercy-at-70th-birthday/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:40,933 || INFO || 1657421991 || #6 ==> Justina Okpoh Celebrates God's Faithfulness And Mercy At 70th Birthday | AIT LIVE]
# [2024-03-13 09:27:40,937 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:42,052 || INFO || _client || HTTP Request: GET https://ait.live/nigerian-us-born-ayo-edebiri-wins-at-75th-primetime-emmy-awards/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:42,226 || INFO || 1657421991 || #7 ==> Nigerian-US Born, Ayo Edebiri Wins At 75th Primetime Emmy Awards | AIT LIVE]
# [2024-03-13 09:27:42,228 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:43,322 || INFO || _client || HTTP Request: GET https://ait.live/golden-globes-awards-2024-oppenheimer-movie-dominates-81st-edition/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:43,467 || INFO || 1657421991 || #8 ==> Golden Globes Awards 2024: "Oppenheimer" movie dominates 81st edition | AIT LIVE]
# [2024-03-13 09:27:43,470 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:44,869 || INFO || _client || HTTP Request: GET https://ait.live/legendary-filmmaker-adedeji-aderemi-dies-at-73/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:45,066 || INFO || 1657421991 || #9 ==> Legendary Filmmaker Adedeji Aderemi Dies At 73 | AIT LIVE]
# [2024-03-13 09:27:45,068 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:46,218 || INFO || _client || HTTP Request: GET https://ait.live/fala-expediting-africas-systemic-change-through-young-leaders/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:46,378 || INFO || 1657421991 || #10 ==> FALA: Expediting Africa's Systemic Change Through Young Leaders | AIT LIVE]
# [2024-03-13 09:27:46,380 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:47,537 || INFO || _client || HTTP Request: GET https://ait.live/american-singer-cardi-b-breaks-up-with-husband-after-6-years-of-marriage/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:47,688 || INFO || 1657421991 || #11 ==> American Singer Cardi B Breaks Up With Husband After 6 Years Of Marriage | AIT LIVE]
# [2024-03-13 09:27:47,691 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:48,865 || INFO || _client || HTTP Request: GET https://ait.live/nigerias-firstlady-attends-senate-presidents-birthday-in-uyo/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:48,967 || INFO || 1657421991 || #12 ==> Nigeria's Firstlady attends Senate President's birthday in Uyo | AIT LIVE]
# [2024-03-13 09:27:48,970 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:48,976 || INFO || 1657421991 || ENTERTAINMENT CONTENTS SAVED TO CSV SUCCESSFULLY.]
# [2024-03-13 09:27:48,977 || INFO || 1657421991 || '
# >>> SPORTS CATEGORY']
# [2024-03-13 09:27:48,980 || INFO || 1657421991 || Scraping page 1/2]
# [2024-03-13 09:27:50,980 || INFO || _client || HTTP Request: GET https://ait.live/category/sports/page/1/ "HTTP/1.1 301 Moved Permanently"]
# [2024-03-13 09:27:51,411 || INFO || _client || HTTP Request: GET https://ait.live/category/sports/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:52,731 || INFO || _client || HTTP Request: GET https://ait.live/caf-confederation-cup-rivers-united-to-face-usm-alger-in-quarter-finals/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:52,908 || INFO || 1657421991 || #1 ==> CAF Confederation Cup: Rivers United To Face USM Alger In Quarter-Finals  | AIT LIVE]
# [2024-03-13 09:27:52,910 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:54,082 || INFO || _client || HTTP Request: GET https://ait.live/2023-african-games-nigeria-continue-dominance-in-womens-weightlifting/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:54,273 || INFO || 1657421991 || #2 ==> 2023 African Games: Nigeria continue dominance in Women's weightlifting | AIT LIVE]
# [2024-03-13 09:27:54,277 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:56,507 || INFO || _client || HTTP Request: GET https://ait.live/athletics-federation-unveils-amusan-brume-47-others-for-africa-games/ "HTTP/1.1 403 Forbidden"]
# [2024-03-13 09:27:56,523 || INFO || 1657421991 || #3 ==> WordPress › Error]
# [2024-03-13 09:27:56,524 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:57,592 || INFO || _client || HTTP Request: GET https://ait.live/africa-games-nigeria-wins-five-medals-in-weightlifting/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:57,756 || INFO || 1657421991 || #4 ==> Africa Games: Nigeria Wins Five Medals In Weightlifting | AIT LIVE]
# [2024-03-13 09:27:57,760 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:27:58,856 || INFO || _client || HTTP Request: GET https://ait.live/african-games-team-nigeria-win-6-gold-medals-in-women-wrestling/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:27:58,972 || INFO || 1657421991 || #5 ==> African Games: Team Nigeria Win 6 Gold Medals In Women Wrestling | AIT LIVE]
# [2024-03-13 09:27:58,975 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:00,135 || INFO || _client || HTTP Request: GET https://ait.live/african-games-flying-eagles-desperate-for-victory-against-south-sudan/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:00,368 || INFO || 1657421991 || #6 ==> African Games: Flying Eagles Desperate For Victory Against South Sudan | AIT LIVE]
# [2024-03-13 09:28:00,370 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:01,887 || INFO || _client || HTTP Request: GET https://ait.live/2023-africa-games-nigeria-on-course-for-table-tennis-team-gold/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:02,211 || INFO || 1657421991 || #7 ==> 2023 Africa Games: Nigeria on course for Table Tennis Team Gold | AIT LIVE]
# [2024-03-13 09:28:02,214 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:03,427 || INFO || _client || HTTP Request: GET https://ait.live/african-games-flying-eagles-will-bounce-back-from-uganda-defeat-bosso/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:03,591 || INFO || 1657421991 || #8 ==> African Games: Flying Eagles Will Bounce Back From Uganda Defeat – Bosso | AIT LIVE]
# [2024-03-13 09:28:03,595 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:04,882 || INFO || _client || HTTP Request: GET https://ait.live/african-games-sports-minister-charges-team-nigeria-to-conquer-africa/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:05,056 || INFO || 1657421991 || #9 ==> African Games: Sports Minister charges Team Nigeria To Conquer Africa | AIT LIVE]
# [2024-03-13 09:28:05,058 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:06,257 || INFO || _client || HTTP Request: GET https://ait.live/bosso-unveils-flying-eagles-squad-for-africa-games/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:06,409 || INFO || 1657421991 || #10 ==> Bosso Unveils Flying Eagles’ Squad For Africa Games | AIT LIVE]
# [2024-03-13 09:28:06,412 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:07,301 || INFO || _client || HTTP Request: GET https://ait.live/uefa-introduces-new-champions-league-format/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:07,572 || INFO || 1657421991 || #11 ==> UEFA Introduces New Champions League Format | AIT LIVE]
# [2024-03-13 09:28:07,574 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:08,717 || INFO || _client || HTTP Request: GET https://ait.live/confederation-cup-npfl-applauds-rivers-united-after-qualifying-for-quarter-finals/ "HTTP/1.1 200 OK"]
# [2024-03-13 09:28:08,871 || INFO || 1657421991 || #12 ==> Confederation Cup: NPFL Applauds Rivers United After Qualifying For Quarter-finals | AIT LIVE]
# [2024-03-13 09:28:08,874 || INFO || 1657421991 || --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# [2024-03-13 09:28:08,880 || INFO || 1657421991 || SPORTS CONTENTS SAVED TO CSV SUCCESSFULLY.]
